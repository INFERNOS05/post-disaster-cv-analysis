# %%
import torchvision.transforms.functional as TF

def create_temporal_pair(img):
    img_next = TF.adjust_brightness(img, 1.2)
    img_next = TF.gaussian_blur(img_next, 3)
    img_next = img_next + 0.03 * torch.randn_like(img_next)
    return img, img_next

class TemporalDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, _ = self.dataset[idx]
        return create_temporal_pair(img)

temp_loader = DataLoader(TemporalDataset(subset_dataset), batch_size=64, shuffle=True)
